# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer(as_frame = True)
df = data.frame
df = data.data.copy()
df['target'] = data.target

# df.head()
display(df.head())
print("\n NUMBER OF TOTAL ROWS AND COLUMNS\n ")
display(df.shape)

print("\nSTATISTICAL SUMMARY\n")
display(df.describe())

print("DATA TYPES")
display(df.dtypes)

missing = df.isnull().sum()
display(missing)

missing_per = (df.isnull().sum() / len (df)) * 100

missing_table = pd.DataFrame({"Missing Count ":missing,
                              "Missing Percentage ":missing_per
                              })

display(missing_table)

plt.figure(figsize=(25, 5))
df.isnull().sum().plot(kind='bar')
plt.title("Missing Values by Feature")
plt.xlabel("Features")
plt.ylabel("Number of Missing Values")
plt.xticks(rotation = 45)
plt.show()

display(df.duplicated().sum())
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]
#  NUMBER OF TOTAL ROWS AND COLUMNS
# (569, 31)
# STATISTICAL SUMMARY
#        mean radius  mean texture  ...  worst fractal dimension      target
# count   569.000000    569.000000  ...               569.000000  569.000000
# mean     14.127292     19.289649  ...                 0.083946    0.627417
# std       3.524049      4.301036  ...                 0.018061    0.483918
# min       6.981000      9.710000  ...                 0.055040    0.000000
# 25%      11.700000     16.170000  ...                 0.071460    0.000000
# ...

# %%
df = data.data.copy()
df['target'] = data.target
display(df.head())

print(data.target_names)

X = data.data
y = data.target

display(X.shape)
display(y.shape)
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                  0.11890       0
# 1        20.57         17.77  ...                  0.08902       0
# 2        19.69         21.25  ...                  0.08758       0
# 3        11.42         20.38  ...                  0.17300       0
# 4        20.29         14.34  ...                  0.07678       0
#
# [5 rows x 31 columns]
# ['malignant' 'benign']
# (569, 30)
# (569,)

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42, stratify = y)

from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)

dt_model.fit(X_train, y_train)

y_pred = dt_model.predict(X_test)


from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score,confusion_matrix,ConfusionMatrixDisplay

y_train_pred = dt_model.predict(X_train)

train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred)
train_recall = recall_score(y_train, y_train_pred)
train_f1 = f1_score(y_train, y_train_pred)

# print("*************** DECISION TREE Training Data ***************")
# print("Accuracy :", train_accuracy)
# print("Precision:", train_precision)
# print("Recall   :", train_recall)
# print("F1 Score :", train_f1)



dt_accuracy = accuracy_score(y_test,y_pred)
dt_precision = precision_score(y_test,y_pred)
dt_recall = recall_score(y_test, y_pred)
dt_f1 = f1_score(y_test,y_pred)

# print("************DECISION TREE TESTING DATA****************")
# print("ACCURACY : ",dt_accuracy)
# print("PRECISION : ",dt_precision)
# print("RECALL : ",dt_recall)
# print("F1_SCORE : ",dt_f1)

results = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1 Score"],
    "Training": [
        train_accuracy,
        train_precision,
        train_recall,
        train_f1
    ],
    "Testing": [
        accuracy,
        precision,
        recall,
        f1
    ]
})

display(results)

cm_dt = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm_dt,
    display_labels=['Malignant', 'Benign']
)

disp.plot(cmap='Greens')
plt.title("Confusion Matrix - Decision Tree")
plt.show()
# Out:
#       Metric  Training   Testing
# 0   Accuracy       1.0  0.918129
# 1  Precision       1.0  0.934579
# 2     Recall       1.0  0.934579
# 3   F1 Score       1.0  0.934579

# %%
#LOGISTIC REGRESSION#

# from sklearn.linear_model import SGDClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# lr_model = SGDClassifier(loss="log_loss",max_iter=10,random_state = 42) This can be used only if the No of epochs is too less
# so as to cap the value strictily to the required no of cycles or else we can use the logistic regression in the normal manner

lr_model = LogisticRegression(max_iter=100)
lr_model.fit(X_train_scaled, y_train)

y_pred = lr_model.predict(X_test_scaled)
y_train_pred = lr_model.predict(X_train_scaled)

train_accuracy = accuracy_score(y_train, y_train_pred)
train_precision = precision_score(y_train, y_train_pred)
train_recall = recall_score(y_train, y_train_pred)
train_f1 = f1_score(y_train, y_train_pred)

# print("***************Logisitic Regression Training Data ***************")
# print("Accuracy :", train_accuracy)
# print("Precision:", train_precision)
# print("Recall   :", train_recall)
# print("F1 Score :", train_f1)



lr_accuracy = accuracy_score(y_test, y_pred)
lr_precision = precision_score(y_test, y_pred)
lr_recall = recall_score(y_test, y_pred)
lr_f1 = f1_score(y_test, y_pred)

# print("*******************Logistic Regression Testing Data *******************")
# print("Accuracy :", lr_accuracy)
# print("Precision:", lr_precision)
# print("Recall   :", lr_recall)
# print("F1 Score :", lr_f1)

results = pd.DataFrame({
    "Metric": ["Accuracy", "Precision", "Recall", "F1 Score"],
    "Training": [
        train_accuracy,
        train_precision,
        train_recall,
        train_f1
    ],
    "Testing": [
        accuracy,
        precision,
        recall,
        f1
    ]
})

display(results)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=['Malignant', 'Benign']
)

disp.plot(cmap='Oranges')
plt.title("Confusion Matrix - Logistic Regression")
plt.show()
# Out:
# *************** Training Data ***************
# Accuracy : 0.9874371859296482
# Precision: 0.9841897233201581
# Recall   : 0.996
# F1 Score : 0.9900596421471173
# *******************Logistic Regression*******************
# Accuracy : 0.9883040935672515
# Precision: 0.9906542056074766
# Recall   : 0.9906542056074766
# F1 Score : 0.9906542056074766
#       Metric  Training   Testing
# 0   Accuracy  0.987437  0.918129
# 1  Precision  0.984190  0.934579
# 2     Recall  0.996000  0.934579
# 3   F1 Score  0.990060  0.934579

# %%
results = pd.DataFrame({
    'Model': ['Decision Tree', 'Logistic Regression'],
    'Accuracy': [dt_accuracy, lr_accuracy],
    'Precision': [dt_precision, lr_precision],
    'Recall': [dt_recall, lr_recall],
    'F1 Score': [dt_f1, lr_f1]
})

display(results)

#Comparision table to see which one is good and we can see that LOGISITIC REGRESSION outperformed Decision Tree
# Out:
#                  Model  Accuracy  Precision    Recall  F1 Score
# 0        Decision Tree  0.918129   0.934579  0.934579  0.934579
# 1  Logistic Regression  0.988304   0.990654  0.990654  0.990654
